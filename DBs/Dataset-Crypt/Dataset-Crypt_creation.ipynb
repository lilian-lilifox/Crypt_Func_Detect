# %%
## Requirements
# tqdm==4.64.0
# pandas==1.4.2

# %%
import json
import pandas as pd

from tqdm import tqdm

# %%
flowchart = pd.read_csv("features/flowchart_Dataset-Crypt.csv")
print(flowchart.shape)
# Out:
# (70866, 8)

# %%
flowchart.head()
# Out:
#                                             idb_path     fva func_name  \
# 0  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x9f08  sub_9F08
# 1  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x9f78  sub_9F78
# 2  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0xa134  sub_A134
# 3  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0xa1fc  sub_A1FC
# 4  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0xa3a8  sub_A3A8
#
#   start_ea  end_ea  bb_num                                            bb_list  \
# 0   0x9f08  0x9f70       7   0x9f08;0x9f2c;0x9f34;0x9f40;0x9f58;0x9f5c;0x9f68
# 1   0x9f78  0xa12c      26  0x9f78;0x9fb4;0x9fbc;0x9fc8;0x9fe0;0x9fe4;0x9f...
# 2   0xa134  0xa1f0       5                 0xa134;0xa184;0xa1d4;0xa1e4;0xa1e8
# 3   0xa1fc  0xa390      15  0xa1fc;0xa240;0xa274;0xa288;0xa2a8;0xa2c0;0xa2...
# 4   0xa3a8  0xa484      11  0xa3a8;0xa3e0;0xa3ec;0xa3f8;0xa414;0xa420;0xa4...
#
#                                          hashopcodes
# 0  78c077a3201f161d8cc3295d70740dd63f43fb28df6e24...
# 1  00ccb536292e4e1c610f5debc461ec5bf6caecae25f290...
# 2  c17b45cb2f60685b3dd9114caf4e254860e37739d6f0cb...
# 3  6fb6708f474314bcef9959020588a1d4963712f4eaf5e4...
# 4  e9c43ea0a0b178a61e5e8272e51671d1c47c29afde21cc...

# %%
flowchart.groupby(["idb_path"]).count()
# Out:
#                                                      fva  func_name  start_ea  \
# idb_path
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64   7398       7398      7398
# IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20....  1518       1518      1518
# IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so...   942        942       942
# IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2....   214        214       214
# IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2...    86         86        86
# IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23....   320        320       320
# IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64      1238       1238      1238
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5....  3566       3566      3566
# IDBs/Dataset-Crypt/arm64/arm64-libcrypto.so.3.i64   7934       7934      7934
# IDBs/Dataset-Crypt/arm64/arm64-libgcrypt.so.20....  1582       1582      1582
# IDBs/Dataset-Crypt/arm64/arm64-libmbedcrypto.so...   974        974       974
# IDBs/Dataset-Crypt/arm64/arm64-libmbedtls.so.2....   228        228       228
# IDBs/Dataset-Crypt/arm64/arm64-libmbedx509.so.2...    92         92        92
# IDBs/Dataset-Crypt/arm64/arm64-libsodium.so.23....   338        338       338
# IDBs/Dataset-Crypt/arm64/arm64-libssl.so.3.i64      1358       1358      1358
# IDBs/Dataset-Crypt/arm64/arm64-libwolfssl.so.5....  3972       3972      3972
# IDBs/Dataset-Crypt/mips32/mips32-libcrypto.so.3...  8186       8186      8186
# IDBs/Dataset-Crypt/mips32/mips32-libgcrypt.so.2...  1754       1754      1754
# IDBs/Dataset-Crypt/mips32/mips32-libmbedcrypto....  1008       1008      1008
# IDBs/Dataset-Crypt/mips32/mips32-libmbedtls.so....   232        232       232
# IDBs/Dataset-Crypt/mips32/mips32-libmbedx509.so...    98         98        98
# IDBs/Dataset-Crypt/mips32/mips32-libsodium.so.2...   306        306       306
# IDBs/Dataset-Crypt/mips32/mips32-libssl.so.3.i64    1374       1374      1374
# IDBs/Dataset-Crypt/mips32/mips32-libwolfssl.so....  4124       4124      4124
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...  2316       2316      2316
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...    20         20        20
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...    10         10        10
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...  3198       3198      3198
# IDBs/Dataset-Crypt/x86/x86-libcrypto.so.3.i64       7930       7930      7930
# IDBs/Dataset-Crypt/x86/x86-libgcrypt.so.20.4.2.i64  1572       1572      1572
# IDBs/Dataset-Crypt/x86/x86-libmbedcrypto.so.2.2...   988        988       988
# IDBs/Dataset-Crypt/x86/x86-libmbedtls.so.2.28.9...   226        226       226
# IDBs/Dataset-Crypt/x86/x86-libmbedx509.so.2.28....    98         98        98
# IDBs/Dataset-Crypt/x86/x86-libsodium.so.23.3.0.i64   406        406       406
# IDBs/Dataset-Crypt/x86/x86-libssl.so.3.i64          1270       1270      1270
# IDBs/Dataset-Crypt/x86/x86-libwolfssl.so.5.7.2....  3990       3990      3990
#
#                                                     end_ea  bb_num  bb_list  \
# idb_path
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64     7398    7398     7398
# IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20....    1518    1518     1518
# IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so...     942     942      942
# IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2....     214     214      214
# IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2...      86      86       86
# IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23....     320     320      320
# IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64        1238    1238     1238
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5....    3566    3566     3566
# IDBs/Dataset-Crypt/arm64/arm64-libcrypto.so.3.i64     7934    7934     7934
# IDBs/Dataset-Crypt/arm64/arm64-libgcrypt.so.20....    1582    1582     1582
# IDBs/Dataset-Crypt/arm64/arm64-libmbedcrypto.so...     974     974      974
# IDBs/Dataset-Crypt/arm64/arm64-libmbedtls.so.2....     228     228      228
# IDBs/Dataset-Crypt/arm64/arm64-libmbedx509.so.2...      92      92       92
# IDBs/Dataset-Crypt/arm64/arm64-libsodium.so.23....     338     338      338
# IDBs/Dataset-Crypt/arm64/arm64-libssl.so.3.i64        1358    1358     1358
# IDBs/Dataset-Crypt/arm64/arm64-libwolfssl.so.5....    3972    3972     3972
# IDBs/Dataset-Crypt/mips32/mips32-libcrypto.so.3...    8186    8186     8186
# IDBs/Dataset-Crypt/mips32/mips32-libgcrypt.so.2...    1754    1754     1754
# IDBs/Dataset-Crypt/mips32/mips32-libmbedcrypto....    1008    1008     1008
# IDBs/Dataset-Crypt/mips32/mips32-libmbedtls.so....     232     232      232
# IDBs/Dataset-Crypt/mips32/mips32-libmbedx509.so...      98      98       98
# IDBs/Dataset-Crypt/mips32/mips32-libsodium.so.2...     306     306      306
# IDBs/Dataset-Crypt/mips32/mips32-libssl.so.3.i64      1374    1374     1374
# IDBs/Dataset-Crypt/mips32/mips32-libwolfssl.so....    4124    4124     4124
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...    2316    2316     2316
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...      20      20       20
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...      10      10       10
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...    3198    3198     3198
# IDBs/Dataset-Crypt/x86/x86-libcrypto.so.3.i64         7930    7930     7930
# IDBs/Dataset-Crypt/x86/x86-libgcrypt.so.20.4.2.i64    1572    1572     1572
# IDBs/Dataset-Crypt/x86/x86-libmbedcrypto.so.2.2...     988     988      988
# IDBs/Dataset-Crypt/x86/x86-libmbedtls.so.2.28.9...     226     226      226
# IDBs/Dataset-Crypt/x86/x86-libmbedx509.so.2.28....      98      98       98
# IDBs/Dataset-Crypt/x86/x86-libsodium.so.23.3.0.i64     406     406      406
# IDBs/Dataset-Crypt/x86/x86-libssl.so.3.i64            1270    1270     1270
# IDBs/Dataset-Crypt/x86/x86-libwolfssl.so.5.7.2....    3990    3990     3990
#
#                                                     hashopcodes
# idb_path
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64          7398
# IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20....         1518
# IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so...          942
# IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2....          214
# IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2...           86
# IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23....          320
# IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64             1238
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5....         3566
# IDBs/Dataset-Crypt/arm64/arm64-libcrypto.so.3.i64          7934
# IDBs/Dataset-Crypt/arm64/arm64-libgcrypt.so.20....         1582
# IDBs/Dataset-Crypt/arm64/arm64-libmbedcrypto.so...          974
# IDBs/Dataset-Crypt/arm64/arm64-libmbedtls.so.2....          228
# IDBs/Dataset-Crypt/arm64/arm64-libmbedx509.so.2...           92
# IDBs/Dataset-Crypt/arm64/arm64-libsodium.so.23....          338
# IDBs/Dataset-Crypt/arm64/arm64-libssl.so.3.i64             1358
# IDBs/Dataset-Crypt/arm64/arm64-libwolfssl.so.5....         3972
# IDBs/Dataset-Crypt/mips32/mips32-libcrypto.so.3...         8186
# IDBs/Dataset-Crypt/mips32/mips32-libgcrypt.so.2...         1754
# IDBs/Dataset-Crypt/mips32/mips32-libmbedcrypto....         1008
# IDBs/Dataset-Crypt/mips32/mips32-libmbedtls.so....          232
# IDBs/Dataset-Crypt/mips32/mips32-libmbedx509.so...           98
# IDBs/Dataset-Crypt/mips32/mips32-libsodium.so.2...          306
# IDBs/Dataset-Crypt/mips32/mips32-libssl.so.3.i64           1374
# IDBs/Dataset-Crypt/mips32/mips32-libwolfssl.so....         4124
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...         2316
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...           20
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...           10
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...         3198
# IDBs/Dataset-Crypt/x86/x86-libcrypto.so.3.i64              7930
# IDBs/Dataset-Crypt/x86/x86-libgcrypt.so.20.4.2.i64         1572
# IDBs/Dataset-Crypt/x86/x86-libmbedcrypto.so.2.2...          988
# IDBs/Dataset-Crypt/x86/x86-libmbedtls.so.2.28.9...          226
# IDBs/Dataset-Crypt/x86/x86-libmbedx509.so.2.28....           98
# IDBs/Dataset-Crypt/x86/x86-libsodium.so.23.3.0.i64          406
# IDBs/Dataset-Crypt/x86/x86-libssl.so.3.i64                 1270
# IDBs/Dataset-Crypt/x86/x86-libwolfssl.so.5.7.2....         3990

# %%
source_x86_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/x86/")]["idb_path"].unique().tolist()
source_arm32_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/arm32/")]["idb_path"].unique().tolist()
source_arm64_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/arm64/")]["idb_path"].unique().tolist()
source_mips32_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/mips32/")]["idb_path"].unique().tolist()
source_arm32_idb_path_list
# Out:
# ['IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so.2.28.9.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2.28.9.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2.28.9.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20.4.2.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5.7.2.e624513f.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23.3.0.i64']

# %%
target_x86_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/vul/") & flowchart["idb_path"].str.contains("x86")]["idb_path"].unique().tolist()
target_arm32_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/vul/") & flowchart["idb_path"].str.contains("arm32")]["idb_path"].unique().tolist()
target_arm64_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/vul/") & flowchart["idb_path"].str.contains("arm64")]["idb_path" ].unique().tolist()
target_mips32_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/vul/") & flowchart["idb_path"].str.contains("mips32")]["idb_path"].unique().tolist()
target_arm32_idb_path_list
# Out:
# ['IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f84_1.0.46/arm32-hostapd.i64',
#  'IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f84_1.0.46/arm32-wpa_supplicant.i64',
#  'IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f84_1.0.46/arm32-miwifi-discovery.i64',
#  'IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f84_1.0.46/arm32-validate_data.i64']

# %%
architecture_map = {
    "x86": {
        "source": source_x86_idb_path_list,
        "target": target_x86_idb_path_list,
    },
    "arm32": {
        "source": source_arm32_idb_path_list,
        "target": target_arm32_idb_path_list,
    },
    "arm64": {
        "source": source_arm64_idb_path_list,
        "target": target_arm64_idb_path_list,
    },
    "mips32": {
        "source": source_mips32_idb_path_list,
        "target": target_mips32_idb_path_list,
    },
}

# %%
flowchart_with_func_name = flowchart[(~flowchart["func_name"].str.contains("sub_")) & flowchart["idb_path"].str.contains("/x86/|/arm32/|/arm64/|/mips32/")].copy()

crypto_keywords = [
    "aes", "des", "rc4", "rc5", "rc6", "sha", "md5", "hmac", "hash", "cbc", "ecb",
    "crypt", "rsa", "dsa", "ecdsa", "curve", "poly1305", "chacha", "cipher", "sign",
    "verify", "digest", "tls", "ssl"
]

flowchart_with_func_name["func_name_lower"] = flowchart_with_func_name["func_name"].str.lower()

crypt_funcs = flowchart_with_func_name[flowchart_with_func_name["func_name_lower"].apply(lambda x: any(k in x for k in crypto_keywords))]
crypt_funcs_list = crypt_funcs["func_name"].unique().tolist()

# %%
selected_columns = ['idb_path', 'fva', 'func_name', 'hashopcodes']

# Store the new function pairs
comparison_list = list()

# Iterate over each architecture of the vul test
for arch, data in architecture_map.items():
    print(f"Processing {arch} architecture.")
    # Iterate over each function in the list
    for source_func in tqdm(crypt_funcs_list):
        # Iterate over the selected binaries
        for source_path in data["source"]:
            # Select the source function
            left_row = flowchart[(flowchart['idb_path'] == source_path) & (flowchart['func_name'] == source_func)]
            if left_row.empty:
                continue
            left = list(left_row[selected_columns].values[0])

            # Iterate over the target functions
            right_indexes = flowchart[flowchart['idb_path'].isin(data["target"])].index
            for index in right_indexes:
                right = list(flowchart.loc[index,selected_columns].values)
                comparison_list.append(left+right)

print("All done!!")
# Out:
# Processing x86 architecture.
# 100%|███████████████████████████████████| 2802/2802 [02:08<00:00, 21.79it/s]
# Processing arm32 architecture.
# 100%|███████████████████████████████████| 2802/2802 [32:19<00:00,  1.44it/s]
# Processing arm64 architecture.
# 100%|███████████████████████████████████| 2802/2802 [02:21<00:00, 19.87it/s]
# Processing mips32 architecture.
# 100%|███████████████████████████████████| 2802/2802 [02:19<00:00, 20.07it/s]
# All done!!

# %%
comparison_list[:2]
# Out:
# [['IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so.2.28.9.i64',
#   '0xb228',
#   'mbedtls_aes_setkey_enc',
#   '833b92134f1f1ab2becf94bef53a8208edda7bedba3ab4fc55660302528fe15f',
#   'IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f84_1.0.46/arm32-hostapd.i64',
#   '0x9f08',
#   'sub_9F08',
#   '78c077a3201f161d8cc3295d70740dd63f43fb28df6e24fcdb1f1fc46578aae0'],
#  ['IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so.2.28.9.i64',
#   '0xb228',
#   'mbedtls_aes_setkey_enc',
#   '833b92134f1f1ab2becf94bef53a8208edda7bedba3ab4fc55660302528fe15f',
#   'IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f84_1.0.46/arm32-hostapd.i64',
#   '0x9f78',
#   'sub_9F78',
#   '00ccb536292e4e1c610f5debc461ec5bf6caecae25f29033c3bd7cc4274db41a']]

# %%
# Create a new DataFrame
columns = [x + "_1" for x in selected_columns ] + [x + "_2" for x in selected_columns ]
testing = pd.DataFrame(comparison_list, columns=columns)

# Add the db_type column 
testing['db_type'] = ['XM'] * testing.shape[0]
print(testing.shape)
# Out:
# (12645864, 9)

# %%
# Sort the rows
testing.sort_values(by=['idb_path_1', 'fva_1', 'idb_path_2', 'fva_2'], inplace=True)
testing.reset_index(inplace=True, drop=True)
print(testing.shape)
# Out:
# (12645864, 9)

# %%
# Check that the hashopcodes of the functions to compare are different
for i, row in testing.iterrows():
    if row['hashopcodes_1'] == row['hashopcodes_2']:
        print("MATCH!")
        print(row)

# %%
# Paranoid check
testing.drop_duplicates(inplace=True)
testing.reset_index(inplace=True, drop=True)
print(testing.shape)
# Out:
# (12611649, 9)

# %%
# Remove hashopcodes columns
del testing['hashopcodes_1']
del testing['hashopcodes_2']

# %%
testing.head()
# Out:
#                                           idb_path_1     fva_1  \
# 0  IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  0x100ab8
# 1  IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  0x100ab8
# 2  IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  0x100ab8
# 3  IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  0x100ab8
# 4  IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  0x100ab8
#
#                    func_name_1  \
# 0  ENGINE_load_ssl_client_cert
# 1  ENGINE_load_ssl_client_cert
# 2  ENGINE_load_ssl_client_cert
# 3  ENGINE_load_ssl_client_cert
# 4  ENGINE_load_ssl_client_cert
#
#                                           idb_path_2     fva_2 func_name_2  \
# 0  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x100330  sub_100330
# 1  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x10123c  sub_10123C
# 2  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x101308  sub_101308
# 3  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x101390  sub_101390
# 4  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x101444  sub_101444
#
#   db_type
# 0      XM
# 1      XM
# 2      XM
# 3      XM
# 4      XM

# %%
testing.tail()
# Out:
#                                                  idb_path_1    fva_1  \
# 12611644  IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5...  0xe2b9c
# 12611645  IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5...  0xe2b9c
# 12611646  IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5...  0xe2b9c
# 12611647  IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5...  0xe2b9c
# 12611648  IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5...  0xe2b9c
#
#                      func_name_1  \
# 12611644  wolfSSL_SESSION_free_0
# 12611645  wolfSSL_SESSION_free_0
# 12611646  wolfSSL_SESSION_free_0
# 12611647  wolfSSL_SESSION_free_0
# 12611648  wolfSSL_SESSION_free_0
#
#                                                  idb_path_2    fva_2  \
# 12611644  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0xfd28c
# 12611645  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0xfea48
# 12611646  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0xfeb5c
# 12611647  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0xfec40
# 12611648  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0xfed24
#
#                       func_name_2 db_type
# 12611644                sub_FD28C      XM
# 12611645  auth_sae_process_commit      XM
# 12611646                sub_FEB5C      XM
# 12611647                sub_FEC40      XM
# 12611648                sub_FED24      XM

# %%
testing.groupby(['idb_path_1', 'func_name_1']).count()
# Out:
#                                                                                   fva_1  \
# idb_path_1                                         func_name_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  AES_bi_ige_encrypt              5529
#                                                    AES_cbc_encrypt                 5529
#                                                    AES_ecb_encrypt                 5529
#                                                    AES_ige_encrypt                 5529
#                                                    AES_set_decrypt_key             5529
# ...                                                                                 ...
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5.... wolfSSL_use_psk_identity_hint   5529
#                                                    wolfSSL_version                 5529
#                                                    wolfSSL_want                    5529
#                                                    wolfSSL_write                   5529
#                                                    wolfSSL_writev                  5529
#
#                                                                                   idb_path_2  \
# idb_path_1                                         func_name_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  AES_bi_ige_encrypt                   5529
#                                                    AES_cbc_encrypt                      5529
#                                                    AES_ecb_encrypt                      5529
#                                                    AES_ige_encrypt                      5529
#                                                    AES_set_decrypt_key                  5529
# ...                                                                                      ...
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5.... wolfSSL_use_psk_identity_hint        5529
#                                                    wolfSSL_version                      5529
#                                                    wolfSSL_want                         5529
#                                                    wolfSSL_write                        5529
#                                                    wolfSSL_writev                       5529
#
#                                                                                   fva_2  \
# idb_path_1                                         func_name_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  AES_bi_ige_encrypt              5529
#                                                    AES_cbc_encrypt                 5529
#                                                    AES_ecb_encrypt                 5529
#                                                    AES_ige_encrypt                 5529
#                                                    AES_set_decrypt_key             5529
# ...                                                                                 ...
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5.... wolfSSL_use_psk_identity_hint   5529
#                                                    wolfSSL_version                 5529
#                                                    wolfSSL_want                    5529
#                                                    wolfSSL_write                   5529
#                                                    wolfSSL_writev                  5529
#
#                                                                                   func_name_2  \
# idb_path_1                                         func_name_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  AES_bi_ige_encrypt                    5529
#                                                    AES_cbc_encrypt                       5529
#                                                    AES_ecb_encrypt                       5529
#                                                    AES_ige_encrypt                       5529
#                                                    AES_set_decrypt_key                   5529
# ...                                                                                       ...
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5.... wolfSSL_use_psk_identity_hint         5529
#                                                    wolfSSL_version                       5529
#                                                    wolfSSL_want                          5529
#                                                    wolfSSL_write                         5529
#                                                    wolfSSL_writev                        5529
#
#                                                                                   db_type
# idb_path_1                                         func_name_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  AES_bi_ige_encrypt                5529
#                                                    AES_cbc_encrypt                   5529
#                                                    AES_ecb_encrypt                   5529
#                                                    AES_ige_encrypt                   5529
#                                                    AES_set_decrypt_key               5529
# ...                                                                                   ...
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5.... wolfSSL_use_psk_identity_hint     5529
#                                                    wolfSSL_version                   5529
#                                                    wolfSSL_want                      5529
#                                                    wolfSSL_write                     5529
#                                                    wolfSSL_writev                    5529
#
# [2281 rows x 5 columns]

# %%
testing.groupby(['idb_path_1']).count()
# Out:
#                                                       fva_1  func_name_1  \
# idb_path_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64   3123885      3123885
# IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20....   132696       132696
# IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so...  1896447      1896447
# IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2....   481023       481023
# IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2...   199044       199044
# IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23....   364914       364914
# IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64       735357       735357
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5....  5678283      5678283
#
#                                                     idb_path_2    fva_2  \
# idb_path_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64      3123885  3123885
# IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20....      132696   132696
# IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so...     1896447  1896447
# IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2....      481023   481023
# IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2...      199044   199044
# IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23....      364914   364914
# IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64          735357   735357
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5....     5678283  5678283
#
#                                                     func_name_2  db_type
# idb_path_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64       3123885  3123885
# IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20....       132696   132696
# IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so...      1896447  1896447
# IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2....       481023   481023
# IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2...       199044   199044
# IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23....       364914   364914
# IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64           735357   735357
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5....      5678283  5678283

# %%
testing.groupby(['idb_path_2']).count()
# Out:
#                                                     idb_path_1    fva_1  \
# idb_path_2
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...     5282796  5282796
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...       22810    22810
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...       11405    11405
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...     7294638  7294638
#
#                                                     func_name_1    fva_2  \
# idb_path_2
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...      5282796  5282796
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...        22810    22810
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...        11405    11405
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...      7294638  7294638
#
#                                                     func_name_2  db_type
# idb_path_2
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...      5282796  5282796
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...        22810    22810
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...        11405    11405
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...      7294638  7294638

# %%
# Save the DataFrame to file
testing.to_csv("pairs/pairs_testing_Dataset-Crypt.csv")

# %%
# Save the "selected functions" to a JSON.
# This is useful to limit the IDA analysis to some functions only.

testing_functions = set([tuple(x) for x in testing[['idb_path_1', 'fva_1']].values])
testing_functions |= set([tuple(x) for x in testing[['idb_path_2', 'fva_2']].values])
print("Found {} unique functions".format(len(testing_functions)))

from collections import defaultdict
selected_functions = defaultdict(list)
for t in testing_functions:
    selected_functions[t[0]].append(int(t[1], 16))

# Test
assert(sum([len(v) for v in selected_functions.values()]) == len(testing_functions))

# Save to file
with open("features/selected_Dataset-Crypt.json", "w") as f_out:
    json.dump(selected_functions, f_out)
# Out:
# Found 7810 unique functions

# %%
# Save the "selected functions" to a CSV.
# This will be useful to post-process the results.

# Remove from flowchart the functions that are not used for the testing
dataset = flowchart.copy()
del dataset['bb_list']
del_list = list()
for i, row in dataset.iterrows():
    if not tuple([row['idb_path'], row['fva']]) in testing_functions:
        del_list.append(i)
dataset.drop(del_list, inplace=True)
dataset.reset_index(inplace=True, drop=True)
print(dataset.shape)

# Save to file
dataset.to_csv("testing_Dataset-Crypt.csv")
# Out:
# (10106, 7)
