# %%
## Requirements
# tqdm==4.64.0
# pandas==1.4.2

# %%
import json
import pandas as pd

from tqdm import tqdm

# %%
flowchart = pd.read_csv("features/flowchart_Dataset-Crypt.csv")
print(flowchart.shape)
# Out:
# (32676, 8)

# %%
flowchart.head()
# Out:
#                                             idb_path     fva  \
# 0  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...   0xf30
# 1  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x1240
# 2  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x185c
# 3  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x1b30
# 4  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x1e60
#
#           func_name start_ea  end_ea  bb_num  \
# 0           sub_F30    0xf30   0xf9c       6
# 1          sub_1240   0x1240  0x12fc       6
# 2  AgentExistDetect   0x185c  0x1b04      18
# 3          sub_1B30   0x1b30  0x1e34      21
# 4          sub_1E60   0x1e60  0x2278      27
#
#                                              bb_list  \
# 0                0xf30;0xf50;0xf60;0xf6c;0xf7c;0xf88
# 1          0x1240;0x125c;0x1264;0x1290;0x12ec;0x12f0
# 2  0x185c;0x18b8;0x18e8;0x1930;0x1948;0x19e4;0x19...
# 3  0x1b30;0x1b70;0x1b84;0x1ba0;0x1ba8;0x1bc8;0x1b...
# 4  0x1e60;0x1efc;0x1f14;0x1f20;0x1f2c;0x1f44;0x1f...
#
#                                          hashopcodes
# 0  66e93c6e03ac4c9a5abfbdfd19dcc9e9ecab2171b02384...
# 1  2c2bd7d049a5b3a5e50e670ffe0d27c6933a168450cf0e...
# 2  3cdfb22264846129343c3ca9877e2bf667479dee40da66...
# 3  61da2a79b485945d30d9d8de54d92582d8ecf94db81f20...
# 4  7e4d1c7b998a3c0acbe1fa6bd27b8c0ab3a343a4d62af1...

# %%
flowchart.groupby(["idb_path"]).count()
# Out:
#                                                      fva  func_name  start_ea  \
# idb_path
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64   3699       3699      3699
# IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20....   759        759       759
# IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so...   471        471       471
# IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2....   107        107       107
# IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2...    43         43        43
# IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23....   160        160       160
# IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64       619        619       619
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5....  1783       1783      1783
# IDBs/Dataset-Crypt/arm64/arm64-libcrypto.so.3.i64   3967       3967      3967
# IDBs/Dataset-Crypt/arm64/arm64-libgcrypt.so.20....   791        791       791
# IDBs/Dataset-Crypt/arm64/arm64-libmbedcrypto.so...   487        487       487
# IDBs/Dataset-Crypt/arm64/arm64-libmbedtls.so.2....   114        114       114
# IDBs/Dataset-Crypt/arm64/arm64-libmbedx509.so.2...    46         46        46
# IDBs/Dataset-Crypt/arm64/arm64-libsodium.so.23....   169        169       169
# IDBs/Dataset-Crypt/arm64/arm64-libssl.so.3.i64       679        679       679
# IDBs/Dataset-Crypt/arm64/arm64-libwolfssl.so.5....  1986       1986      1986
# IDBs/Dataset-Crypt/mips32/mips32-libcrypto.so.3...  4093       4093      4093
# IDBs/Dataset-Crypt/mips32/mips32-libgcrypt.so.2...   877        877       877
# IDBs/Dataset-Crypt/mips32/mips32-libmbedcrypto....   504        504       504
# IDBs/Dataset-Crypt/mips32/mips32-libmbedtls.so....   116        116       116
# IDBs/Dataset-Crypt/mips32/mips32-libmbedx509.so...    49         49        49
# IDBs/Dataset-Crypt/mips32/mips32-libsodium.so.2...   153        153       153
# IDBs/Dataset-Crypt/mips32/mips32-libssl.so.3.i64     687        687       687
# IDBs/Dataset-Crypt/mips32/mips32-libwolfssl.so....  2062       2062      2062
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...    10         10        10
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...     5          5         5
# IDBs/Dataset-Crypt/x86/x86-libcrypto.so.3.i64       3965       3965      3965
# IDBs/Dataset-Crypt/x86/x86-libgcrypt.so.20.4.2.i64   786        786       786
# IDBs/Dataset-Crypt/x86/x86-libmbedcrypto.so.2.2...   494        494       494
# IDBs/Dataset-Crypt/x86/x86-libmbedtls.so.2.28.9...   113        113       113
# IDBs/Dataset-Crypt/x86/x86-libmbedx509.so.2.28....    49         49        49
# IDBs/Dataset-Crypt/x86/x86-libsodium.so.23.3.0.i64   203        203       203
# IDBs/Dataset-Crypt/x86/x86-libssl.so.3.i64           635        635       635
# IDBs/Dataset-Crypt/x86/x86-libwolfssl.so.5.7.2....  1995       1995      1995
#
#                                                     end_ea  bb_num  bb_list  \
# idb_path
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64     3699    3699     3699
# IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20....     759     759      759
# IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so...     471     471      471
# IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2....     107     107      107
# IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2...      43      43       43
# IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23....     160     160      160
# IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64         619     619      619
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5....    1783    1783     1783
# IDBs/Dataset-Crypt/arm64/arm64-libcrypto.so.3.i64     3967    3967     3967
# IDBs/Dataset-Crypt/arm64/arm64-libgcrypt.so.20....     791     791      791
# IDBs/Dataset-Crypt/arm64/arm64-libmbedcrypto.so...     487     487      487
# IDBs/Dataset-Crypt/arm64/arm64-libmbedtls.so.2....     114     114      114
# IDBs/Dataset-Crypt/arm64/arm64-libmbedx509.so.2...      46      46       46
# IDBs/Dataset-Crypt/arm64/arm64-libsodium.so.23....     169     169      169
# IDBs/Dataset-Crypt/arm64/arm64-libssl.so.3.i64         679     679      679
# IDBs/Dataset-Crypt/arm64/arm64-libwolfssl.so.5....    1986    1986     1986
# IDBs/Dataset-Crypt/mips32/mips32-libcrypto.so.3...    4093    4093     4093
# IDBs/Dataset-Crypt/mips32/mips32-libgcrypt.so.2...     877     877      877
# IDBs/Dataset-Crypt/mips32/mips32-libmbedcrypto....     504     504      504
# IDBs/Dataset-Crypt/mips32/mips32-libmbedtls.so....     116     116      116
# IDBs/Dataset-Crypt/mips32/mips32-libmbedx509.so...      49      49       49
# IDBs/Dataset-Crypt/mips32/mips32-libsodium.so.2...     153     153      153
# IDBs/Dataset-Crypt/mips32/mips32-libssl.so.3.i64       687     687      687
# IDBs/Dataset-Crypt/mips32/mips32-libwolfssl.so....    2062    2062     2062
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...      10      10       10
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...       5       5        5
# IDBs/Dataset-Crypt/x86/x86-libcrypto.so.3.i64         3965    3965     3965
# IDBs/Dataset-Crypt/x86/x86-libgcrypt.so.20.4.2.i64     786     786      786
# IDBs/Dataset-Crypt/x86/x86-libmbedcrypto.so.2.2...     494     494      494
# IDBs/Dataset-Crypt/x86/x86-libmbedtls.so.2.28.9...     113     113      113
# IDBs/Dataset-Crypt/x86/x86-libmbedx509.so.2.28....      49      49       49
# IDBs/Dataset-Crypt/x86/x86-libsodium.so.23.3.0.i64     203     203      203
# IDBs/Dataset-Crypt/x86/x86-libssl.so.3.i64             635     635      635
# IDBs/Dataset-Crypt/x86/x86-libwolfssl.so.5.7.2....    1995    1995     1995
#
#                                                     hashopcodes
# idb_path
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64          3699
# IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20....          759
# IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so...          471
# IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2....          107
# IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2...           43
# IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23....          160
# IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64              619
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5....         1783
# IDBs/Dataset-Crypt/arm64/arm64-libcrypto.so.3.i64          3967
# IDBs/Dataset-Crypt/arm64/arm64-libgcrypt.so.20....          791
# IDBs/Dataset-Crypt/arm64/arm64-libmbedcrypto.so...          487
# IDBs/Dataset-Crypt/arm64/arm64-libmbedtls.so.2....          114
# IDBs/Dataset-Crypt/arm64/arm64-libmbedx509.so.2...           46
# IDBs/Dataset-Crypt/arm64/arm64-libsodium.so.23....          169
# IDBs/Dataset-Crypt/arm64/arm64-libssl.so.3.i64              679
# IDBs/Dataset-Crypt/arm64/arm64-libwolfssl.so.5....         1986
# IDBs/Dataset-Crypt/mips32/mips32-libcrypto.so.3...         4093
# IDBs/Dataset-Crypt/mips32/mips32-libgcrypt.so.2...          877
# IDBs/Dataset-Crypt/mips32/mips32-libmbedcrypto....          504
# IDBs/Dataset-Crypt/mips32/mips32-libmbedtls.so....          116
# IDBs/Dataset-Crypt/mips32/mips32-libmbedx509.so...           49
# IDBs/Dataset-Crypt/mips32/mips32-libsodium.so.2...          153
# IDBs/Dataset-Crypt/mips32/mips32-libssl.so.3.i64            687
# IDBs/Dataset-Crypt/mips32/mips32-libwolfssl.so....         2062
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...           10
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...            5
# IDBs/Dataset-Crypt/x86/x86-libcrypto.so.3.i64              3965
# IDBs/Dataset-Crypt/x86/x86-libgcrypt.so.20.4.2.i64          786
# IDBs/Dataset-Crypt/x86/x86-libmbedcrypto.so.2.2...          494
# IDBs/Dataset-Crypt/x86/x86-libmbedtls.so.2.28.9...          113
# IDBs/Dataset-Crypt/x86/x86-libmbedx509.so.2.28....           49
# IDBs/Dataset-Crypt/x86/x86-libsodium.so.23.3.0.i64          203
# IDBs/Dataset-Crypt/x86/x86-libssl.so.3.i64                  635
# IDBs/Dataset-Crypt/x86/x86-libwolfssl.so.5.7.2....         1995

# %%
source_x86_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/x86/")]["idb_path"].unique().tolist()
source_arm32_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/arm32/")]["idb_path"].unique().tolist()
source_arm64_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/arm64/")]["idb_path"].unique().tolist()
source_mips32_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/mips32/")]["idb_path"].unique().tolist()
source_arm32_idb_path_list
# Out:
# ['IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so.2.28.9.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2.28.9.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2.28.9.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20.4.2.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5.7.2.e624513f.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64',
#  'IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23.3.0.i64']

# %%
target_x86_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/vul/") & flowchart["idb_path"].str.contains("x86")]["idb_path"].unique().tolist()
target_arm32_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/vul/") & flowchart["idb_path"].str.contains("arm32")]["idb_path"].unique().tolist()
target_arm64_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/vul/") & flowchart["idb_path"].str.contains("arm64")]["idb_path" ].unique().tolist()
target_mips32_idb_path_list = flowchart[flowchart["idb_path"].str.contains("/vul/") & flowchart["idb_path"].str.contains("mips32")]["idb_path"].unique().tolist()
target_arm32_idb_path_list
# Out:
# ['IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f84_1.0.46/arm32-miwifi-discovery.i64',
#  'IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f84_1.0.46/arm32-validate_data.i64']

# %%
architecture_map = {
    "x86": {
        "source": source_x86_idb_path_list,
        "target": target_x86_idb_path_list,
    },
    "arm32": {
        "source": source_arm32_idb_path_list,
        "target": target_arm32_idb_path_list,
    },
    "arm64": {
        "source": source_arm64_idb_path_list,
        "target": target_arm64_idb_path_list,
    },
    "mips32": {
        "source": source_mips32_idb_path_list,
        "target": target_mips32_idb_path_list,
    },
}

# %%
flowchart_with_func_name = flowchart[(~flowchart["func_name"].str.contains("sub_")) & flowchart["idb_path"].str.contains("/x86/|/arm32/|/arm64/|/mips32/")].copy()

crypto_keywords = [
    "aes", "des", "rc4", "sha", "md5", "hmac", "hash",
    "cbc", "ecb", "rsa", "dsa", "ecdsa", "curve", "poly1305", "chacha"
]

flowchart_with_func_name["func_name_lower"] = flowchart_with_func_name["func_name"].str.lower()

crypt_funcs = flowchart_with_func_name[flowchart_with_func_name["func_name_lower"].apply(lambda x: any(k in x for k in crypto_keywords))]
crypt_funcs_list = crypt_funcs["func_name"].unique().tolist()

# %%
# 初始化一个字典来存储每个关键字的函数数量
keyword_counts = {}

# 遍历每个加密关键字
for keyword in crypto_keywords:
    # 筛选包含该关键字的函数
    keyword_funcs = crypt_funcs[crypt_funcs["func_name_lower"].str.contains(keyword, case=False, na=False)]
    # 统计唯一函数名的数量
    count = keyword_funcs["func_name"].nunique()
    # 存储结果
    keyword_counts[keyword] = count

# 转换为 DataFrame 以便更好展示
keyword_counts_df = pd.DataFrame.from_dict(keyword_counts, orient='index', columns=['Function Count'])

# 打印结果
print(keyword_counts_df)

# 可选：按数量降序排序
keyword_counts_df = keyword_counts_df.sort_values(by='Function Count', ascending=False)
print("\nSorted by Function Count:\n", keyword_counts_df)
# Out:
#           Function Count
# aes                   67
# des                   60
# rc4                   10
# sha                  103
# md5                   12
# hmac                  44
# hash                  81
# cbc                   34
# ecb                    9
# rsa                  164
# dsa                  103
# ecdsa                 22
# curve                 55
# poly1305              38
# chacha                37
#
# Sorted by Function Count:
#            Function Count
# rsa                  164
# dsa                  103
# sha                  103
# hash                  81
# aes                   67
# des                   60
# curve                 55
# hmac                  44
# poly1305              38
# chacha                37
# cbc                   34
# ecdsa                 22
# md5                   12
# rc4                   10
# ecb                    9

# %%
selected_columns = ['idb_path', 'fva', 'func_name', 'hashopcodes']

# Store the new function pairs
comparison_list = list()

# Iterate over each architecture of the vul test
for arch, data in architecture_map.items():
    print(f"Processing {arch} architecture.")
    # Iterate over each function in the list
    for source_func in tqdm(crypt_funcs_list):
        # Iterate over the selected binaries
        for source_path in data["source"]:
            # Select the source function
            left_row = flowchart[(flowchart['idb_path'] == source_path) & (flowchart['func_name'] == source_func)]
            if left_row.empty:
                continue
            left = list(left_row[selected_columns].values[0])

            # Iterate over the target functions
            right_indexes = flowchart[flowchart['idb_path'].isin(data["target"])].index
            for index in right_indexes:
                right = list(flowchart.loc[index,selected_columns].values)
                comparison_list.append(left+right)

print("All done!!")
# Out:
# Processing x86 architecture.
# 100%|█████████████████████████████████████| 720/720 [00:16<00:00, 44.21it/s]
# Processing arm32 architecture.
# 100%|█████████████████████████████████████| 720/720 [00:17<00:00, 42.15it/s]
# Processing arm64 architecture.
# 100%|█████████████████████████████████████| 720/720 [00:16<00:00, 44.42it/s]
# Processing mips32 architecture.
# 100%|█████████████████████████████████████| 720/720 [00:16<00:00, 42.90it/s]
# All done!!

# %%
comparison_list[:2]
# Out:
# [['IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so.2.28.9.i64',
#   '0xb228',
#   'mbedtls_aes_setkey_enc',
#   '833b92134f1f1ab2becf94bef53a8208edda7bedba3ab4fc55660302528fe15f',
#   'IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f84_1.0.46/arm32-miwifi-discovery.i64',
#   '0xf30',
#   'sub_F30',
#   '66e93c6e03ac4c9a5abfbdfd19dcc9e9ecab2171b02384b7e11165d693deb133'],
#  ['IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so.2.28.9.i64',
#   '0xb228',
#   'mbedtls_aes_setkey_enc',
#   '833b92134f1f1ab2becf94bef53a8208edda7bedba3ab4fc55660302528fe15f',
#   'IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f84_1.0.46/arm32-miwifi-discovery.i64',
#   '0x1240',
#   'sub_1240',
#   '2c2bd7d049a5b3a5e50e670ffe0d27c6933a168450cf0e058f01ad21c9896af6']]

# %%
# Create a new DataFrame
columns = [x + "_1" for x in selected_columns ] + [x + "_2" for x in selected_columns ]
testing = pd.DataFrame(comparison_list, columns=columns)

# Add the db_type column 
testing['db_type'] = ['XM'] * testing.shape[0]
print(testing.shape)
# Out:
# (8910, 9)

# %%
# Sort the rows
testing.sort_values(by=['idb_path_1', 'fva_1', 'idb_path_2', 'fva_2'], inplace=True)
testing.reset_index(inplace=True, drop=True)
print(testing.shape)
# Out:
# (8910, 9)

# %%
# Check that the hashopcodes of the functions to compare are different
for i, row in testing.iterrows():
    if row['hashopcodes_1'] == row['hashopcodes_2']:
        print("MATCH!")
        print(row)

# %%
# Paranoid check
testing.drop_duplicates(inplace=True)
testing.reset_index(inplace=True, drop=True)
print(testing.shape)
# Out:
# (8910, 9)

# %%
# Remove hashopcodes columns
del testing['hashopcodes_1']
del testing['hashopcodes_2']

# %%
testing.head()
# Out:
#                                           idb_path_1     fva_1  \
# 0  IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  0x10e980
# 1  IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  0x10e980
# 2  IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  0x10e980
# 3  IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  0x10e980
# 4  IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  0x10e980
#
#                               func_name_1  \
# 0  EVP_PKEY_CTX_set_dsa_paramgen_md_props
# 1  EVP_PKEY_CTX_set_dsa_paramgen_md_props
# 2  EVP_PKEY_CTX_set_dsa_paramgen_md_props
# 3  EVP_PKEY_CTX_set_dsa_paramgen_md_props
# 4  EVP_PKEY_CTX_set_dsa_paramgen_md_props
#
#                                           idb_path_2   fva_2  \
# 0  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x1240
# 1  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x185c
# 2  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x1b30
# 3  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x1e60
# 4  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x22b4
#
#         func_name_2 db_type
# 0          sub_1240      XM
# 1  AgentExistDetect      XM
# 2          sub_1B30      XM
# 3          sub_1E60      XM
# 4          sub_22B4      XM

# %%
testing.tail()
# Out:
#                                              idb_path_1    fva_1  \
# 8905  IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5...  0xd8be0
# 8906  IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5...  0xd8be0
# 8907  IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5...  0xd8be0
# 8908  IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5...  0xd8be0
# 8909  IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5...  0xd8be0
#
#                    func_name_1  \
# 8905  wolfSSL_X509_NAME_hash_0
# 8906  wolfSSL_X509_NAME_hash_0
# 8907  wolfSSL_X509_NAME_hash_0
# 8908  wolfSSL_X509_NAME_hash_0
# 8909  wolfSSL_X509_NAME_hash_0
#
#                                              idb_path_2   fva_2 func_name_2  \
# 8905  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...  0x1038    sub_1038
# 8906  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...   0x698        main
# 8907  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...   0xc70     sub_C70
# 8908  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...   0xd34     sub_D34
# 8909  IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7...   0xdf8     sub_DF8
#
#      db_type
# 8905      XM
# 8906      XM
# 8907      XM
# 8908      XM
# 8909      XM

# %%
testing.groupby(['idb_path_1', 'func_name_1']).count()
# Out:
#                                                                                         fva_1  \
# idb_path_1                                         func_name_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  AES_bi_ige_encrypt                      15
#                                                    AES_cbc_encrypt                         15
#                                                    AES_ecb_encrypt                         15
#                                                    AES_ige_encrypt                         15
#                                                    AES_set_decrypt_key                     15
# ...                                                                                       ...
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5.... wolfSSL_i2d_DSA_SIG                     15
#                                                    wolfSSL_i2d_DSAparams                   15
#                                                    wolfSSL_i2d_ECDSA_SIG                   15
#                                                    wolfSSL_shallow_sk_dup                  15
#                                                    wolfSSL_sk_ACCESS_DESCRIPTION_value     15
#
#                                                                                         idb_path_2  \
# idb_path_1                                         func_name_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  AES_bi_ige_encrypt                           15
#                                                    AES_cbc_encrypt                              15
#                                                    AES_ecb_encrypt                              15
#                                                    AES_ige_encrypt                              15
#                                                    AES_set_decrypt_key                          15
# ...                                                                                            ...
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5.... wolfSSL_i2d_DSA_SIG                          15
#                                                    wolfSSL_i2d_DSAparams                        15
#                                                    wolfSSL_i2d_ECDSA_SIG                        15
#                                                    wolfSSL_shallow_sk_dup                       15
#                                                    wolfSSL_sk_ACCESS_DESCRIPTION_value          15
#
#                                                                                         fva_2  \
# idb_path_1                                         func_name_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  AES_bi_ige_encrypt                      15
#                                                    AES_cbc_encrypt                         15
#                                                    AES_ecb_encrypt                         15
#                                                    AES_ige_encrypt                         15
#                                                    AES_set_decrypt_key                     15
# ...                                                                                       ...
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5.... wolfSSL_i2d_DSA_SIG                     15
#                                                    wolfSSL_i2d_DSAparams                   15
#                                                    wolfSSL_i2d_ECDSA_SIG                   15
#                                                    wolfSSL_shallow_sk_dup                  15
#                                                    wolfSSL_sk_ACCESS_DESCRIPTION_value     15
#
#                                                                                         func_name_2  \
# idb_path_1                                         func_name_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  AES_bi_ige_encrypt                            15
#                                                    AES_cbc_encrypt                               15
#                                                    AES_ecb_encrypt                               15
#                                                    AES_ige_encrypt                               15
#                                                    AES_set_decrypt_key                           15
# ...                                                                                             ...
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5.... wolfSSL_i2d_DSA_SIG                           15
#                                                    wolfSSL_i2d_DSAparams                         15
#                                                    wolfSSL_i2d_ECDSA_SIG                         15
#                                                    wolfSSL_shallow_sk_dup                        15
#                                                    wolfSSL_sk_ACCESS_DESCRIPTION_value           15
#
#                                                                                         db_type
# idb_path_1                                         func_name_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64  AES_bi_ige_encrypt                        15
#                                                    AES_cbc_encrypt                           15
#                                                    AES_ecb_encrypt                           15
#                                                    AES_ige_encrypt                           15
#                                                    AES_set_decrypt_key                       15
# ...                                                                                         ...
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5.... wolfSSL_i2d_DSA_SIG                       15
#                                                    wolfSSL_i2d_DSAparams                     15
#                                                    wolfSSL_i2d_ECDSA_SIG                     15
#                                                    wolfSSL_shallow_sk_dup                    15
#                                                    wolfSSL_sk_ACCESS_DESCRIPTION_value       15
#
# [594 rows x 5 columns]

# %%
testing.groupby(['idb_path_1']).count()
# Out:
#                                                     fva_1  func_name_1  \
# idb_path_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64    1875         1875
# IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20....     75           75
# IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so...   1815         1815
# IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2....    180          180
# IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2...     15           15
# IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23....    690          690
# IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64        150          150
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5....   4110         4110
#
#                                                     idb_path_2  fva_2  \
# idb_path_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64         1875   1875
# IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20....          75     75
# IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so...        1815   1815
# IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2....         180    180
# IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2...          15     15
# IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23....         690    690
# IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64             150    150
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5....        4110   4110
#
#                                                     func_name_2  db_type
# idb_path_1
# IDBs/Dataset-Crypt/arm32/arm32-libcrypto.so.3.i64          1875     1875
# IDBs/Dataset-Crypt/arm32/arm32-libgcrypt.so.20....           75       75
# IDBs/Dataset-Crypt/arm32/arm32-libmbedcrypto.so...         1815     1815
# IDBs/Dataset-Crypt/arm32/arm32-libmbedtls.so.2....          180      180
# IDBs/Dataset-Crypt/arm32/arm32-libmbedx509.so.2...           15       15
# IDBs/Dataset-Crypt/arm32/arm32-libsodium.so.23....          690      690
# IDBs/Dataset-Crypt/arm32/arm32-libssl.so.3.i64              150      150
# IDBs/Dataset-Crypt/arm32/arm32-libwolfssl.so.5....         4110     4110

# %%
testing.groupby(['idb_path_2']).count()
# Out:
#                                                     idb_path_1  fva_1  \
# idb_path_2
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...        5940   5940
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...        2970   2970
#
#                                                     func_name_1  fva_2  \
# idb_path_2
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...         5940   5940
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...         2970   2970
#
#                                                     func_name_2  db_type
# idb_path_2
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...         5940     5940
# IDBs/Dataset-Crypt/vul/miwifi_ra80_firmware_e7f...         2970     2970

# %%
# Save the DataFrame to file
testing.to_csv("pairs/pairs_testing_Dataset-Crypt.csv")

# %%
# Save the "selected functions" to a JSON.
# This is useful to limit the IDA analysis to some functions only.

testing_functions = set([tuple(x) for x in testing[['idb_path_1', 'fva_1']].values])
testing_functions |= set([tuple(x) for x in testing[['idb_path_2', 'fva_2']].values])
print("Found {} unique functions".format(len(testing_functions)))

from collections import defaultdict
selected_functions = defaultdict(list)
for t in testing_functions:
    selected_functions[t[0]].append(int(t[1], 16))

# Test
assert(sum([len(v) for v in selected_functions.values()]) == len(testing_functions))

# Save to file
with open("features/selected_Dataset-Crypt.json", "w") as f_out:
    json.dump(selected_functions, f_out)
# Out:
# Found 609 unique functions

# %%
# Save the "selected functions" to a CSV.
# This will be useful to post-process the results.

# Remove from flowchart the functions that are not used for the testing
dataset = flowchart.copy()
del dataset['bb_list']
del_list = list()
for i, row in dataset.iterrows():
    if not tuple([row['idb_path'], row['fva']]) in testing_functions:
        del_list.append(i)
dataset.drop(del_list, inplace=True)
dataset.reset_index(inplace=True, drop=True)
print(dataset.shape)

# Save to file
dataset.to_csv("testing_Dataset-Crypt.csv")
# Out:
# (609, 7)
